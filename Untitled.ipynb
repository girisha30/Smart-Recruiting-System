# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("Resume_data.csv")

# %%
df
# Out:
#                         Name  \
# 0         Aastha(resume).pdf
# 1         Girisha Resume.pdf
# 2         Kenny-Baustert.pdf
# 3        Kevin-Jefferson.pdf
# 4   Krishnamraju-Kammili.pdf
# ..                       ...
# 82        Weixiang-Zhang.pdf
# 83           Will-Ediger.pdf
# 84             Will-Yang.pdf
# 85      Yakoub-Beldjehem.pdf
# 86          Yuchen-Liang.pdf
#
#                                               Context  \
# 0   AASTHA MAGGU\r\n494/1 Rajguru Street College r...
# 1   GIRISHA\r\n girisha3012@gmail.com  9815689155 ...
# 2   Kenny Baustert\r\nWeb Developer\r\nLakeland, F...
# 3   Kevin Jefferson\r\nUI DEVELOPER/DESIGNER\r\nSa...
# 4   Krishnamraju Kammili\r\nMEAN Web Developer - H...
# ..                                                ...
# 82  Weixiang Zhang\r\nSoftware Developer\r\nSan Fr...
# 83  Will Ediger\r\nActuarial Software Developer\r\...
# 84  Will Yang\r\nSoftware Developer - Epic Systems...
# 85  Yakoub Beldjehem\r\nSoftware Developer\r\nDes ...
# 86  Yuchen Liang\r\nUnion City, CA - Email me on I...
#
#                                               Cleaned  \
# 0   AASTHA MAGGU Rajguru Street College road Civil...
# 1   GIRISHA httpsgithubcomgirisha30 httplinkedinco...
# 2   Kenny Baustert web developer Lakeland FL Email...
# 3   Kevin Jefferson UI DEVELOPERDESIGNER San Jose ...
# 4   Krishnamraju Kammili MEAN web developer Hall M...
# ..                                                ...
# 82  Weixiang Zhang Software Developer San Francisc...
# 83  Will Ediger Actuarial Software Developer Overl...
# 84  Yang Software Developer Epic Systems Email ind...
# 85  Yakoub Beldjehem Software Developer Des Moines...
# 86  Yuchen Liang Union City CA Email indeed indeed...
#
#                                             Selective  \
# 0   assessment Language use steady Javascript ease...
# 1   Web CCPython Language skillsi computer CJava n...
# 2   user Full jQuery Incentives client iba campus ...
# 3   Web user knowledge CISCO manager Adobe De inde...
# 4   thorough agency jQuery Handlebars Passport dir...
# ..                                                ...
# 82  relocate knowledge ensure Eclipse client Modif...
# 83  prevent ADDITIONAL improved Designed indeed St...
# 84  Center nonproduction Eclipse ADDITIONAL transf...
# 85  ACCESS user knowledge statement Eclipse ADDITI...
# 86  Achievement user knowledge campus client Profe...
#
#                                     Selective_Reduced  \
# 0   assessment Language Javascript python brs acco...
# 1   Web CCPython Language skillsi computer CJava n...
# 2   user Full jQuery Incentives client iba campus ...
# 3   Web user knowledge CISCO manager Adobe De inde...
# 4   agency jQuery Handlebars Passport directive us...
# ..                                                ...
# 82  knowledge Eclipse client Modified Los ADDITION...
# 83  ADDITIONAL EDUCATION research HTML August time...
# 84  Center nonproduction Eclipse ADDITIONAL transf...
# 85  ACCESS user knowledge statement Eclipse ADDITI...
# 86  Achievement user knowledge campus client Profe...
#
#                                              TF_Based
# 0   10th 12th aastha aasthamaggu10gmailcom accord ...
# 1   10th 12th 4th accordingly achieve algorithms a...
# 2   ability accessibility adaptive additional adob...
# 3   aa adapt additional adobe advanced ajax analyt...
# 4   agile ajax angular application catholic code c...
# ..                                                ...
# 82  adapt additional adequate advanced analysis an...
# 83  access accommodate actuarial additional adhoc ...
# 84  additional algorithm allot allow api applicati...
# 85  12c aas access activities activity adapters ad...
# 86  3d academic accomplish accomplishment achieve ...
#
# [87 rows x 6 columns]

# %%
df.shape
# Out:
# (87, 6)

# %%
df.shape[0]
# Out:
# 87

# %%
df['Scores'] = 10

# %%
df
# Out:
#                         Name  \
# 0         Aastha(resume).pdf
# 1         Girisha Resume.pdf
# 2         Kenny-Baustert.pdf
# 3        Kevin-Jefferson.pdf
# 4   Krishnamraju-Kammili.pdf
# ..                       ...
# 82        Weixiang-Zhang.pdf
# 83           Will-Ediger.pdf
# 84             Will-Yang.pdf
# 85      Yakoub-Beldjehem.pdf
# 86          Yuchen-Liang.pdf
#
#                                               Context  \
# 0   AASTHA MAGGU\r\n494/1 Rajguru Street College r...
# 1   GIRISHA\r\n girisha3012@gmail.com  9815689155 ...
# 2   Kenny Baustert\r\nWeb Developer\r\nLakeland, F...
# 3   Kevin Jefferson\r\nUI DEVELOPER/DESIGNER\r\nSa...
# 4   Krishnamraju Kammili\r\nMEAN Web Developer - H...
# ..                                                ...
# 82  Weixiang Zhang\r\nSoftware Developer\r\nSan Fr...
# 83  Will Ediger\r\nActuarial Software Developer\r\...
# 84  Will Yang\r\nSoftware Developer - Epic Systems...
# 85  Yakoub Beldjehem\r\nSoftware Developer\r\nDes ...
# 86  Yuchen Liang\r\nUnion City, CA - Email me on I...
#
#                                               Cleaned  \
# 0   AASTHA MAGGU Rajguru Street College road Civil...
# 1   GIRISHA httpsgithubcomgirisha30 httplinkedinco...
# 2   Kenny Baustert web developer Lakeland FL Email...
# 3   Kevin Jefferson UI DEVELOPERDESIGNER San Jose ...
# 4   Krishnamraju Kammili MEAN web developer Hall M...
# ..                                                ...
# 82  Weixiang Zhang Software Developer San Francisc...
# 83  Will Ediger Actuarial Software Developer Overl...
# 84  Yang Software Developer Epic Systems Email ind...
# 85  Yakoub Beldjehem Software Developer Des Moines...
# 86  Yuchen Liang Union City CA Email indeed indeed...
#
#                                             Selective  \
# 0   assessment Language use steady Javascript ease...
# 1   Web CCPython Language skillsi computer CJava n...
# 2   user Full jQuery Incentives client iba campus ...
# 3   Web user knowledge CISCO manager Adobe De inde...
# 4   thorough agency jQuery Handlebars Passport dir...
# ..                                                ...
# 82  relocate knowledge ensure Eclipse client Modif...
# 83  prevent ADDITIONAL improved Designed indeed St...
# 84  Center nonproduction Eclipse ADDITIONAL transf...
# 85  ACCESS user knowledge statement Eclipse ADDITI...
# 86  Achievement user knowledge campus client Profe...
#
#                                     Selective_Reduced  \
# 0   assessment Language Javascript python brs acco...
# 1   Web CCPython Language skillsi computer CJava n...
# 2   user Full jQuery Incentives client iba campus ...
# 3   Web user knowledge CISCO manager Adobe De inde...
# 4   agency jQuery Handlebars Passport directive us...
# ..                                                ...
# 82  knowledge Eclipse client Modified Los ADDITION...
# 83  ADDITIONAL EDUCATION research HTML August time...
# 84  Center nonproduction Eclipse ADDITIONAL transf...
# 85  ACCESS user knowledge statement Eclipse ADDITI...
# 86  Achievement user knowledge campus client Profe...
#
#                                              TF_Based  Scores
# 0   10th 12th aastha aasthamaggu10gmailcom accord ...      10
# 1   10th 12th 4th accordingly achieve algorithms a...      10
# 2   ability accessibility adaptive additional adob...      10
# 3   aa adapt additional adobe advanced ajax analyt...      10
# 4   agile ajax angular application catholic code c...      10
# ..                                                ...     ...
# 82  adapt additional adequate advanced analysis an...      10
# 83  access accommodate actuarial additional adhoc ...      10
# 84  additional algorithm allot allow api applicati...      10
# 85  12c aas access activities activity adapters ad...      10
# 86  3d academic accomplish accomplishment achieve ...      10
#
# [87 rows x 7 columns]

# %%
sns.heatmap(df.corr(), annot = True)
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\matrix.py:194: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\matrix.py:199: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# <AxesSubplot:>

# %%
sns.load_dataset("tips")
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
