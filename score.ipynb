# %%
import PyPDF2
import os
import pickle
import shutil
import textract
from pptx import Presentation
from odf import text, teletype
from odf.opendocument import load
import zipfile
import patoolib
from datetime import datetime
import calendar
import string
import re
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.stem import PorterStemmer
from bs4 import BeautifulSoup as bs
import params


d = datetime.utcnow()
unixtime = calendar.timegm(d.utctimetuple())

lemmatizer = WordNetLemmatizer()
port = PorterStemmer()


def exclude_string(text, file):
    vectorizer, classifier = model_opener()

    if any(s in text.lower() for s in params.exclude_list):
        print("Excluded by keywords: " + file)
        if not os.path.exists(params.FILTER_PATH + "rejected resumes"):
            os.makedirs(params.FILTER_PATH + "rejected resumes")
        shutil.copy(params.CVPATH + file, params.FILTER_PATH + "rejected resumes")

    else:
        # text = preprocessor(text)
        sample_resume = vectorizer.transform([text]).toarray()
        prediction = classifier.predict(sample_resume)
        prob = classifier.predict_proba(sample_resume)

        # Write prediction probability into log file
        log_writer(file, prob)

        file_seperator(prob, prediction, file)


def model_opener():
    ##Open Vectorizer model
    with open(params.PKL_VECTOR, 'rb') as file:
        vectorizer = pickle.load(file)

    ##Open Classifier model
    with open(params.PKL_MODEL, 'rb') as file:
        classifier = pickle.load(file)

    return vectorizer, classifier


def preprocessor(each_resume):
    each_resume = each_resume.translate(str.maketrans('', '', string.punctuation))
    each_resume = each_resume.translate(str.maketrans('', '', "\n"))
    #each_resume = each_resume.translate(str.maketrans('', '', "\t"))
    #each_resume = each_resume.translate(str.maketrans('', '', " "))
    each_resume = re.sub(r'[\x00-\x08\x0b\x0c\x0e-\x1f\x7f-\xff]', ' ', each_resume)
    each_resume = lemmatizer.lemmatize(each_resume)
    each_resume = port.stem(each_resume)

    return each_resume


def file_seperator(prob, prediction, file):
    if prob[:, 1][0] >= 0.6:
        print("This is the Resume of the filtered candidate for software developer post: " + file + " " + str(round(prob[:, 1][0]*100, 2)) + "%")
        if not os.path.exists(params.FILTER_PATH + "selected resumes"):
            os.makedirs(params.FILTER_PATH + "selected resumes")
        shutil.copy(params.CVPATH + file, params.FILTER_PATH + "selected resumes")
    else:
        print("This is the resume of the rejected candidate : " + file + " " + str(round(prob[:, 1][0]*100, 2)) + "%")
        if not os.path.exists(params.FILTER_PATH + "rejected resumes"):
            os.makedirs(params.FILTER_PATH + "rejected resumes")
        shutil.copy(params.CVPATH + file, params.FILTER_PATH + "rejected resumes")


def log_writer(file, pred_prob):
    with open(params.LOG_PATH + 'prob_{}.txt'.format(str(unixtime)), "a") as myfile:
        myfile.write(file + ";" + str(round(pred_prob[:, 1][0]*100, 2)) + "\n")


def textract_reader(filename):
    text = textract.process(filename)
    return text.decode('utf-8')


def pdf_reader(CVPATH, file):

    try:
        f = open(CVPATH + file, "rb")
        pdfReader = PyPDF2.PdfFileReader(f)
        num_pages = pdfReader.numPages
        count = 0
        text = ""
        # The while loop will read each page
        while count < num_pages:
            pageObj = pdfReader.getPage(count)
            count += 1
            text += pageObj.extractText()

        exclude_string(text, file)

    except Exception as e:
        print("Unable to handle the " + file)
        if not os.path.exists(params.FILTER_PATH + "exception"):
            os.makedirs(params.FILTER_PATH + "exception")
        shutil.copy(CVPATH + file, params.FILTER_PATH + "exception")


def docx_odt_reader(CVPATH, file):

    try:
        alltext = ' '
        word = textract_reader(CVPATH + file)
        each_resume = " "
        for j in range(len(word)):
            each_resume += word[j]

        exclude_string(each_resume, file)


    except Exception as e:
        print("Unable to handle the " + file)
        if not os.path.exists(params.FILTER_PATH + "exception"):
            os.makedirs(params.FILTER_PATH + "exception")
        shutil.copy(CVPATH + file, params.FILTER_PATH + "exception")


def doc_opener(CVPATH, file):

    try:
        soup = bs(open(CVPATH + file, encoding="Latin-1").read(), features="lxml")
        [s.extract() for s in soup(['style', 'script'])]
        word = soup.get_text()
        #word = "".join("".join(tmpText.split('\t')).split('\n')).encode('utf-8').strip()
        each_resume = " "
        for j in range(len(word)):
            each_resume += word[j]

        exclude_string(each_resume, file)


    except Exception as e:
        print("Unable to handle the " + file)
        if not os.path.exists(params.FILTER_PATH + "exception"):
            os.makedirs(params.FILTER_PATH + "exception")

        shutil.copy(CVPATH + file, params.FILTER_PATH + "exception")


def pptx_opener(CVPATH, file):

    try:
        f = open(CVPATH + file, "rb")
        prs = Presentation(f)

        each_resume = " "
        for slide in prs.slides:
            for shape in slide.shapes:
                if hasattr(shape, "text"):
                    word = shape.text

                for j in range(len(word)):
                    each_resume += word[j]

        exclude_string(each_resume, file)


    except Exception as e:
        print("Unable to handle the " + file)
        if not os.path.exists(params.FILTER_PATH + "exception"):
            os.makedirs(params.FILTER_PATH + "exception")
        shutil.copy(CVPATH + file, params.FILTER_PATH + "exception")


def odp_reader(CVPATH, file):
    vectorizer, classifier = model_opener()
    try:
        textdoc = load(CVPATH + file)
        allparas = textdoc.getElementsByType(text.P)
        each_resume = ' '
        for i in range(len(allparas)):
            word = teletype.extractText(allparas[i])
            for j in range(len(word)):
                each_resume += word[j]

        exclude_string(each_resume, file)


    except Exception as e:
        print("Unable to handle the " + file)
        if not os.path.exists(params.FILTER_PATH + "exception"):
            os.makedirs(params.FILTER_PATH + "exception")
        shutil.copy(CVPATH + file, params.FILTER_PATH + "exception")


def zipdir_reader(EXTRACT_PATH):
        # Remove all the files in zipextract dir
        for file in os.scandir(EXTRACT_PATH):
            os.unlink(file.path)

        for r, d, f in os.walk(EXTRACT_PATH):
            for file in f:
                # Read pdf files
                if str(file).split(".")[-1].lower() == "pdf":
                    pdf_reader(EXTRACT_PATH, file)

                # Read docx and odt files
                elif str(file).split(".")[-1].lower() == "docx" or str(file).split(".")[1].lower() == "odt":
                    docx_odt_reader(EXTRACT_PATH, file)

                # If file is doc move it into temp_data folder and convert into docx. Then process and remove that files from temp dir
                elif str(file).split(".")[-1].lower() == "docm" or \
                        str(file).split(".")[-1].lower() == "dot" or \
                        str(file).split(".")[-1].lower() == "dotx":
                    doc_opener(EXTRACT_PATH, file)

                # Read pptx files
                elif str(file).split(".")[-1].lower() == "pptx":
                    pptx_opener(EXTRACT_PATH, file)

                elif str(file).split(".")[-1].lower() == "odp":
                    odp_reader(EXTRACT_PATH, file)

                else:
                    if not os.path.exists(params.FILTER_PATH + "rejected resumes"):
                        os.makedirs(params.FILTER_PATH + "rejected resumes")
                    shutil.copy(EXTRACT_PATH + file, params.FILTER_PATH + "rejected resumes")


def copy_sub_dir_files(EXTRACT_PATH):
    for root, dirs, files in os.walk(EXTRACT_PATH):
        if root != EXTRACT_PATH:
            for root, dirs, files in os.walk(root):
                for file in files:
                    print(root + "/" + file)
                    shutil.copy(root + "/" + file, EXTRACT_PATH)
                shutil.rmtree(root)


def main():

    try:
        ##Read Files by looking at the extension
        for r, d, f in os.walk(params.CVPATH):
            for file in f:
                # Read pdf files
                if str(file).split(".")[-1].lower() == "pdf":
                    pdf_reader(params.CVPATH, file)

                #Read docx and odt files
                elif str(file).split(".")[-1].lower() == "docx" or str(file).split(".")[1].lower() == "odt":
                    docx_odt_reader(params.CVPATH, file)

                # If file is doc move it into temp_data folder and convert into docx. Then process and remove that files from temp dir
                elif str(file).split(".")[-1].lower() == "doc" or \
                        str(file).split(".")[-1].lower() == "docm" or \
                        str(file).split(".")[-1].lower() == "dot" or \
                        str(file).split(".")[-1].lower() == "dotx":
                    doc_opener(params.CVPATH, file)

                # Read pptx files
                elif str(file).split(".")[-1].lower() == "pptx":
                    pptx_opener(params.CVPATH, file)

                elif str(file).split(".")[-1].lower() == "odp":
                    odp_reader(params.CVPATH, file)

                # Zip extractor
                elif str(file).split(".")[-1].lower() == "zip":
                    with zipfile.ZipFile(params.CVPATH + file, 'r') as zip_ref:
                        zip_ref.extractall(params.EXTRACT_PATH)
                    copy_sub_dir_files(params.EXTRACT_PATH)
                    zipdir_reader(params.EXTRACT_PATH)

                elif str(file).split(".")[-1].lower() == "rar":
                    patoolib.extract_archive(params.CVPATH + file, outdir=params.EXTRACT_PATH)
                    copy_sub_dir_files(params.EXTRACT_PATH)
                    zipdir_reader(params.EXTRACT_PATH)

                else:
                    if not os.path.exists(params.FILTER_PATH + "rejected resumes"):
                        os.makedirs(params.FILTER_PATH + "rejected resumes")
                    shutil.copy(params.CVPATH + file, params.FILTER_PATH + "rejected resumes")

    except Exception as e:
        print(str(e))


if __name__ == '__main__':
    main()
# Out:
# This is the Resume of the filtered candidate for software developer post: Aastha(resume).pdf 62.0%
# This is the Resume of the filtered candidate for software developer post: Girisha Resume.pdf 62.0%
# This is the resume of the rejected candidate : Jorge-Delacadena.pdf 42.0%
# This is the resume of the rejected candidate : Joshua-Norman.pdf 39.0%
# This is the resume of the rejected candidate : Julia-Velarde.pdf 17.0%
# This is the resume of the rejected candidate : K-Ersaggi.pdf 25.0%
# This is the resume of the rejected candidate : Katherine-Tamboer.pdf 33.0%
# This is the Resume of the filtered candidate for software developer post: Kenny-Baustert.pdf 76.0%
# This is the Resume of the filtered candidate for software developer post: Kevin-Jefferson.pdf 65.0%
# This is the resume of the rejected candidate : Kham-Lam.pdf 42.0%
# This is the resume of the rejected candidate : Kirsten-Murphy.pdf 27.0%
# This is the Resume of the filtered candidate for software developer post: Krishnamraju-Kammili.pdf 64.0%
# This is the resume of the rejected candidate : Kristin-Gardner.pdf 28.0%
# This is the Resume of the filtered candidate for software developer post: Kristopher-Scheppe.pdf 69.0%
# This is the resume of the rejected candidate : Laura-Tullio.pdf 47.0%
# This is the Resume of the filtered candidate for software developer post: Lora-Hong.pdf 75.0%
# This is the Resume of the filtered candidate for software developer post: madhavi-d.pdf 78.0%
# This is the Resume of the filtered candidate for software developer post: Mahantesh-Shivasangappa.pdf 69.0%
# This is the Resume of the filtered candidate for software developer post: manasa-h.pdf 72.0%
# This is the Resume of the filtered candidate for software developer post: Mandeep-Saini.pdf 85.0%
# This is the Resume of the filtered candidate for software developer post: MANOHAR-M.pdf 70.0%
# This is the resume of the rejected candidate : Marcela-Garcia.pdf 21.0%
# This is the resume of the rejected candidate : Matt-Hamlin.pdf 55.0%
# This is the resume of the rejected candidate : Matthew-Augustin.pdf 27.0%
# This is the Resume of the filtered candidate for software developer post: Matthew-Brozen.pdf 63.0%
# This is the resume of the rejected candidate : Matthew-Lisiak.pdf 54.0%
# This is the Resume of the filtered candidate for software developer post: Matthew-Padich.pdf 86.0%
# This is the Resume of the filtered candidate for software developer post: Michael-Berry.pdf 66.0%
# This is the resume of the rejected candidate : Michael-Culp---Animator.pdf 25.0%
# This is the resume of the rejected candidate : Michael-Mallis.pdf 39.0%
# This is the resume of the rejected candidate : Michael-Ryan.pdf 31.0%
# This is the resume of the rejected candidate : Miles-Johnson.pdf 43.0%
# This is the Resume of the filtered candidate for software developer post: Minhaz-Shaikh.pdf 75.0%
# This is the resume of the rejected candidate : Miranda-Festler.pdf 17.0%
# This is the resume of the rejected candidate : Miranda-Modys.pdf 24.0%
# This is the resume of the rejected candidate : Molly-Sotak.pdf 20.0%
# This is the resume of the rejected candidate : Monica-Seferian.pdf 35.0%
# This is the Resume of the filtered candidate for software developer post: Mourya-Allagadda.pdf 71.0%
# This is the Resume of the filtered candidate for software developer post: Mukti-Patel.pdf 62.0%
# This is the Resume of the filtered candidate for software developer post: Mussie-Ghebregziabher.pdf 70.0%
# This is the resume of the rejected candidate : Myles-Goethe.pdf 20.0%
# This is the Resume of the filtered candidate for software developer post: N.-Prasoona.pdf 72.0%
# This is the Resume of the filtered candidate for software developer post: Nandini-K.pdf 67.0%
# This is the resume of the rejected candidate : Nasir-Ahmad-Khan.pdf 52.0%
# This is the resume of the rejected candidate : Natalie-Abernethy.pdf 21.0%
# This is the resume of the rejected candidate : Nathan-Holland.pdf 31.0%
# This is the Resume of the filtered candidate for software developer post: Nathan-Thorpe.pdf 82.0%
# This is the resume of the rejected candidate : Nathen-Gross.pdf 36.0%
# This is the Resume of the filtered candidate for software developer post: Nelson-Christian.pdf 72.0%
# This is the resume of the rejected candidate : Nicholas-Stephas.pdf 22.0%
# This is the Resume of the filtered candidate for software developer post: Nick-Carfagno.pdf 68.0%
# This is the resume of the rejected candidate : Nick-Mendoza.pdf 28.0%
# This is the Resume of the filtered candidate for software developer post: Nidhi-Mittal.pdf 71.0%
# This is the resume of the rejected candidate : Nitesh-Bajracharya.pdf 58.0%
# This is the resume of the rejected candidate : Oleg-McNamara.pdf 38.0%
# This is the Resume of the filtered candidate for software developer post: Oleksandr-Makhno.pdf 74.0%
# This is the resume of the rejected candidate : Oleksandra-Dreval.pdf 35.0%
# This is the resume of the rejected candidate : Oliver-Wade.pdf 39.0%
# This is the Resume of the filtered candidate for software developer post: Omar-Diaz.pdf 72.0%
# This is the Resume of the filtered candidate for software developer post: Omnia-Shoukry.pdf 66.0%
# This is the Resume of the filtered candidate for software developer post: Orestes-Triantafyllos.pdf 75.0%
# This is the resume of the rejected candidate : Patrick-Macatangga.pdf 51.0%
# This is the Resume of the filtered candidate for software developer post: Patrick-Shea.pdf 75.0%
# This is the resume of the rejected candidate : Paul-Clark.pdf 38.0%
# This is the resume of the rejected candidate : Paul-Elliott.pdf 43.0%
# This is the resume of the rejected candidate : Paul-LeBlond.pdf 59.0%
# This is the resume of the rejected candidate : Paul-V.pdf 34.0%
# This is the resume of the rejected candidate : Phillip-Britain.pdf 57.0%
# This is the Resume of the filtered candidate for software developer post: pranay-S.pdf 83.0%
# This is the resume of the rejected candidate : Prathyusha-Bomma.pdf 58.0%
# This is the Resume of the filtered candidate for software developer post: Pravesh-Surani.pdf 68.0%
# This is the Resume of the filtered candidate for software developer post: Preksha-Shah.pdf 79.0%
# This is the Resume of the filtered candidate for software developer post: Prerana-Lanjil.pdf 65.0%
# This is the Resume of the filtered candidate for software developer post: Priya-Web-Developer.pdf 66.0%
# This is the Resume of the filtered candidate for software developer post: Quan-Khu.pdf 66.0%
# This is the Resume of the filtered candidate for software developer post: Radhika-Reddy.pdf 70.0%
# This is the Resume of the filtered candidate for software developer post: Rahul-Maddineni.pdf 66.0%
# This is the Resume of the filtered candidate for software developer post: Rajesh-A.pdf 77.0%
# This is the Resume of the filtered candidate for software developer post: Rakesh-Nangunoori.pdf 61.0%
# This is the Resume of the filtered candidate for software developer post: Rakhee-Makhijani.pdf 67.0%
# This is the resume of the rejected candidate : Ramses-Gonzalez.pdf 57.0%
# This is the Resume of the filtered candidate for software developer post: Ranjini-Devi-Ramakrishnan.pdf 71.0%
# This is the resume of the rejected candidate : Raul-Alpizar.pdf 55.0%
# This is the resume of the rejected candidate : Remon-Dawoud.pdf 42.0%
# This is the Resume of the filtered candidate for software developer post: Rex-Steel.pdf 79.0%
# This is the Resume of the filtered candidate for software developer post: Rick-Doll.pdf 70.0%
# This is the Resume of the filtered candidate for software developer post: Robert-Bruce.pdf 69.0%
# This is the resume of the rejected candidate : Robert-Hanna.pdf 34.0%
# This is the resume of the rejected candidate : Rodolfo-Baez.pdf 29.0%
# This is the Resume of the filtered candidate for software developer post: Ronak-Desai.pdf 74.0%
# This is the Resume of the filtered candidate for software developer post: Russ-Berge.pdf 75.0%
# This is the resume of the rejected candidate : Ryan-Chapman.pdf 32.0%
# This is the Resume of the filtered candidate for software developer post: S-Ramakrishna.pdf 74.0%
# This is the Resume of the filtered candidate for software developer post: Sai-Pujari.pdf 70.0%
# This is the Resume of the filtered candidate for software developer post: Sam-Lucyk.pdf 63.0%
# This is the Resume of the filtered candidate for software developer post: Samuel-Goerdel.pdf 64.0%
# This is the Resume of the filtered candidate for software developer post: Sandeep-J.pdf 77.0%
# This is the Resume of the filtered candidate for software developer post: Sanjar-Hakimi.pdf 76.0%
# This is the Resume of the filtered candidate for software developer post: Sanjaya-Shrestha.pdf 63.0%
# This is the resume of the rejected candidate : Sarah-Talbot.pdf 27.0%
# This is the Resume of the filtered candidate for software developer post: Saurabh-Mahamine.pdf 74.0%
# This is the resume of the rejected candidate : Scott-Evenson.pdf 59.0%
# This is the resume of the rejected candidate : Scott-Hill.pdf 52.0%
# This is the resume of the rejected candidate : Scott-Szabados.pdf 33.0%
# This is the resume of the rejected candidate : Sean-Frye.pdf 47.0%
# This is the Resume of the filtered candidate for software developer post: Sekhar-M.pdf 78.0%
# This is the Resume of the filtered candidate for software developer post: Serhiy-Prokopenko.pdf 81.0%
# This is the Resume of the filtered candidate for software developer post: Seth-Harper.pdf 62.0%
# This is the Resume of the filtered candidate for software developer post: Sevki-Eray-Acar.pdf 64.0%
# This is the Resume of the filtered candidate for software developer post: shaik-r.pdf 78.0%
# This is the resume of the rejected candidate : Sharp-Photographer.pdf 36.0%
# This is the resume of the rejected candidate : Shashank-Dogra.pdf 56.0%
# This is the Resume of the filtered candidate for software developer post: Shashank-Moghe.pdf 69.0%
# This is the resume of the rejected candidate : Shashank-Pantra-Thyaga.pdf 56.0%
# This is the resume of the rejected candidate : Shefali-Malhotra.pdf 58.0%
# This is the resume of the rejected candidate : Shinhye-Kim.pdf 20.0%
# This is the Resume of the filtered candidate for software developer post: Shioshankar-Malewar.pdf 75.0%
# This is the Resume of the filtered candidate for software developer post: shireesha-n.pdf 83.0%
# This is the Resume of the filtered candidate for software developer post: Siddhartha-Konakanchi.pdf 77.0%
# This is the resume of the rejected candidate : Simon-H.-You.pdf 24.0%
# This is the Resume of the filtered candidate for software developer post: Sindhuja-Akkanti.pdf 77.0%
# This is the Resume of the filtered candidate for software developer post: Sk.-Sohail.pdf 79.0%
# This is the Resume of the filtered candidate for software developer post: Sneha-Sarnagari.pdf 72.0%
# This is the Resume of the filtered candidate for software developer post: Solar-Uros.pdf 76.0%
# This is the resume of the rejected candidate : Sonnye-Lim.pdf 32.0%
# This is the Resume of the filtered candidate for software developer post: Sruthi-Vegesna.pdf 74.0%
# This is the resume of the rejected candidate : Stephanie-Battistoni.pdf 42.0%
# This is the Resume of the filtered candidate for software developer post: Stephanie-Gaufin.pdf 64.0%
# This is the Resume of the filtered candidate for software developer post: Stephen-Price.pdf 68.0%
# This is the resume of the rejected candidate : Steven-Bowman.pdf 15.0%
# This is the Resume of the filtered candidate for software developer post: Sudheer-Sundalam.pdf 74.0%
# This is the Resume of the filtered candidate for software developer post: Sumana-Achanta.pdf 70.0%
# Excluded by keywords: Svetlana-Sargsian.pdf
# This is the resume of the rejected candidate : Tai-Beaumont.pdf 47.0%
# This is the Resume of the filtered candidate for software developer post: Tek-Pokhrel.pdf 79.0%
# This is the resume of the rejected candidate : Tharani-Konreddy.pdf 57.0%
# This is the Resume of the filtered candidate for software developer post: Thomas-Chen.pdf 73.0%
# This is the resume of the rejected candidate : Tod-Deppe.pdf 25.0%
# This is the Resume of the filtered candidate for software developer post: Tom-Savlidis.pdf 60.0%
# This is the resume of the rejected candidate : Tommy-Cha.pdf 33.0%
# This is the Resume of the filtered candidate for software developer post: Tommy-Woo.pdf 84.0%
# This is the resume of the rejected candidate : Troy-Lai.pdf 52.0%
# This is the resume of the rejected candidate : Tsedalu-Gebeyehu.pdf 57.0%
# This is the Resume of the filtered candidate for software developer post: Tyler-Gustafson.pdf 71.0%
# This is the Resume of the filtered candidate for software developer post: Vaishnavi-Goud.pdf 71.0%
# This is the resume of the rejected candidate : Vanessa-Landeros.pdf 38.0%
# This is the Resume of the filtered candidate for software developer post: Vatsal-Thakor.pdf 68.0%
# This is the Resume of the filtered candidate for software developer post: Venkata-Rao-Mukkapati0.pdf 77.0%
# This is the resume of the rejected candidate : Victor-Ekpo.pdf 51.0%
# This is the Resume of the filtered candidate for software developer post: Victor-Martinez.pdf 76.0%
# This is the resume of the rejected candidate : Vikki-Courtenay.pdf 22.0%
# This is the resume of the rejected candidate : Vincent-DeCampo.pdf 57.0%
# This is the resume of the rejected candidate : Vincent-Tilghman.pdf 26.0%
# This is the resume of the rejected candidate : Vishal-Kumar-Gupta.pdf 57.0%
# This is the Resume of the filtered candidate for software developer post: Weixiang-Zhang.pdf 75.0%
# This is the resume of the rejected candidate : Wes-Bernick.pdf 39.0%
# This is the Resume of the filtered candidate for software developer post: Will-Ediger.pdf 62.0%
# This is the Resume of the filtered candidate for software developer post: Will-Yang.pdf 70.0%
# This is the Resume of the filtered candidate for software developer post: Yakoub-Beldjehem.pdf 64.0%
# This is the resume of the rejected candidate : Yasser-Osuna.pdf 51.0%
# This is the Resume of the filtered candidate for software developer post: Yuchen-Liang.pdf 70.0%
# This is the resume of the rejected candidate : Zhenzhong-Mao.pdf 57.0%
